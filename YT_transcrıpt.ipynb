# %% [markdown]
# <a href="https://colab.research.google.com/github/Stephenthomas10/Projects-and-implementations/blob/main/YT_transcr%C4%B1pt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

YouTubeTranscriptApi.get_transcript("YLccHH7bS7g")
# Out:
# [{'text': "let's take a look at Azure machine",
#   'start': 0.06,
#   'duration': 5.78},
#  {'text': 'learning starting at the very top',
#   'start': 1.979,
#   'duration': 3.861},
#  {'text': '[Music]', 'start': 7.0, 'duration': 6.2},
#  {'text': 'welcome to this video on Azure machine',
#   'start': 10.8,
#   'duration': 4.919},
#  {'text': "learning my name is Kevin feasel I'm the",
#   'start': 13.2,
#   'duration': 5.4},
#  {'text': 'proprietor of catalyxy Services LLC a',
#   'start': 15.719,
#   'duration': 4.56},
#  {'text': 'consulting firm which specializes in',
#   'start': 18.6,
#   'duration': 3.78},
#  {'text': 'work all across the data platform space',
#   'start': 20.279,
#   'duration': 4.861},
#  {'text': "especially SQL Server we're going to",
#   'start': 22.38,
#   'duration': 4.62},
#  {'text': 'start a new series on Azure machine',
#   'start': 25.14,
#   'duration': 3.899},
#  {'text': 'learning this will be a multi-part',
#   'start': 27.0,
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# Replace 'video_id' with your actual video ID
video_id = "YLccHH7bS7g"

# Fetch the transcript
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# Extract and concatenate the text from the transcript
continuous_text = " ".join([entry['text'] for entry in transcript])

print(continuous_text)
# Out:
# let's take a look at Azure machine learning starting at the very top [Music] welcome to this video on Azure machine learning my name is Kevin feasel I'm the proprietor of catalyxy Services LLC a consulting firm which specializes in work all across the data platform space especially SQL Server we're going to start a new series on Azure machine learning this will be a multi-part series where I'll start with the basics of how it all works and move down from there along the way we'll have videos on automated machine learning using the Azure ml designers graphical user interface a writing code against the python SDK and even implementing a simple form of ml Ops machine learning operations using GitHub actions there's a lot of ground we're going to cover and this series will supplement three separate presentations I deliver on Azure ml if we want to start with Azure machine learning I think it's a good idea to understand what it is we're getting ourselves into and that means an architectur
# ...
